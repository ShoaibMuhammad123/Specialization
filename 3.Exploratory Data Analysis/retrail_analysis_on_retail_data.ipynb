# %% [markdown]
# ## **Retail Analysis**

# %% [markdown]
# `Dataset Description:`
# * The dataset represents retail transactional data. It contains information about customers, their purchases, products, and transaction details. The data includes various attributes such as customer ID, name, email, phone, address, city, state, zipcode, country, age, gender, income, customer segment, last purchase date, total purchases, amount spent, product category, product brand, product type, feedback, shipping method, payment method, and order status.
# * `Key Points`:
# ### **Customer Information**:
# * Includes customer details like ID, name, email, phone, address, city, state, zipcode, country, age, and gender. Customer segments are categorized into Premium, Regular, and New.
# ### **Transaction Details**:
# * Transaction-specific data such as transaction ID, last purchase date, total purchases, amount spent, total purchase amount, feedback, shipping method, payment method, and order status.
# ### **Product Information**:
# Contains product-related details such as product category, brand, and type. Products are categorized into electronics, clothing, grocery, books, and home decor.
# ### **Geographic Information**:
# * Contains location details including city, state, and country. Available for various countries including USA, UK, Canada, Australia, and Germany.
# ### **Temporal Information**:
# Last purchase date is provided along with separate columns for year, month, date, and time. Allows analysis based on temporal patterns and trends.
# ### **Data Quality**:
# * Some rows contain null values, and others are duplicates, which may need to be handled during data preprocessing. Null values are randomly distributed across rows. Duplicate rows are available at different parts of the dataset.
# ## **Potential Analysis**:
# * Customer segmentation analysis based on demographics, purchase behavior, and feedback. Sales trend analysis over time to identify peak seasons or trends. Product performance analysis to determine popular categories, brands, or types. Geographic analysis to understand regional preferences and trends. Payment and shipping method analysis to optimize services. Customer satisfaction analysis based on feedback and order status.
# ### **Data Preprocessing**:
# * Handling null values and duplicates. Parsing and formatting temporal data. Encoding categorical variables. Scaling numerical variables if required. Splitting data into training and testing sets for modeling.

# %%
import pandas as pd

# %%
df = pd.read_csv('new_retail_data.csv')

# %%
df.shape
# Out:
# (302010, 30)

# %%
df.head()
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# ...

# %%
df.tail()
# Out:
#         Transaction_ID  Customer_ID            Name                     Email  \
# 302005       4246475.0      12104.0    Meagan Ellis      Courtney60@gmail.com
# 302006       1197603.0      69772.0     Mathew Beck      Jennifer71@gmail.com
# 302007       7743242.0      28449.0      Daniel Lee  Christopher100@gmail.com
# 302008       9301950.0      45477.0  Patrick Wilson       Rebecca65@gmail.com
# 302009       2882826.0      53626.0  Dustin Merritt       William14@gmail.com
#
#                Phone                       Address        City  \
# 302005  7.466354e+09        389 Todd Path Apt. 159  Townsville
# 302006  5.754305e+09             52809 Mark Forges     Hanover
# 302007  9.382530e+09  407 Aaron Crossing Suite 495    Brighton
# 302008  9.373222e+09               3204 Baird Port     Halifax
# 302009  9.518927e+09           143 Amanda Crescent      Tucson
#
#                   State  Zipcode    Country  ...  Total_Amount  \
# ...

# %%
df.sample(4)
# Out:
#         Transaction_ID  Customer_ID             Name                Email  \
# 143108       3049769.0      85722.0     Terry Curtis  Candace15@gmail.com
# 163480       7569314.0      28538.0      Mark Hudson      Ann53@gmail.com
# 244062       3855196.0      88889.0      Ashley Gray  Herbert99@gmail.com
# 301335       3594213.0      84237.0  Rhonda Williams   Samuel40@gmail.com
#
#                Phone                     Address           City    State  \
# 143108  6.109638e+09           00650 Cook Tunnel  San Francisco    Maine
# 163480  2.990479e+09  55027 Jill Ports Suite 606       New York   Kansas
# 244062  9.943179e+09           7230 Leslie Point        Halifax  Ontario
# 301335  5.842092e+09           39541 Dixon Drive     Portsmouth  England
#
#         Zipcode Country  ...  Total_Amount Product_Category  \
# 143108   9595.0     USA  ...    117.460117       Home Decor
# 163480  99597.0     USA  ...   1393.486221       Home Decor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %%
df.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# min        18.000000    2023.000000         1.000000      10.000219
# ...

# %%
numeric_cols = [col for col in df.columns if df[col].dtype!='object']
categorical_cols = [col for col in df.columns if df[col].dtype=='object']

# %%
numeric_cols
# Out:
# ['Transaction_ID',
#  'Customer_ID',
#  'Phone',
#  'Zipcode',
#  'Age',
#  'Year',
#  'Total_Purchases',
#  'Amount',
#  'Total_Amount',
#  'Ratings']

# %%
categorical_cols
# Out:
# ['Name',
#  'Email',
#  'Address',
#  'City',
#  'State',
#  'Country',
#  'Gender',
#  'Income',
#  'Customer_Segment',
#  'Date',
#  'Month',
#  'Time',
#  'Product_Category',
#  'Product_Brand',
#  'Product_Type',
#  'Feedback',
#  'Shipping_Method',
#  'Payment_Method',
#  'Order_Status',
#  'products']

# %%
df.shape
# Out:
# (302010, 30)

# %%
df.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund           Berlin  77985.0
# 1  6.852900e+09  82072 Dawn Centers  Nottingham          England  99071.0
# 2  8.362160e+09   4133 Young Canyon     Geelong  New South Wales  75929.0
#
#      Country  ...  Total_Amount Product_Category  Product_Brand Product_Type  \
# 0    Germany  ...    324.086270         Clothing           Nike       Shorts
# 1         UK  ...    806.707815      Electronics        Samsung       Tablet
# 2  Australia  ...   1063.432799            Books  Penguin Books   Children's
#
#     Feedback  Shipping_Method Payment_Method Order_Status  Ratings  \
# ...

# %%
num_df = df[numeric_cols]

# %%
num_df.head()
# Out:
#    Transaction_ID  Customer_ID         Phone  Zipcode   Age    Year  \
# 0       8691788.0      37249.0  1.414787e+09  77985.0  21.0  2023.0
# 1       2174773.0      69749.0  6.852900e+09  99071.0  19.0  2023.0
# 2       6679610.0      30192.0  8.362160e+09  75929.0  48.0  2023.0
# 3       7232460.0      62101.0  2.776752e+09  88420.0  56.0  2023.0
# 4       4983775.0      27901.0  9.098268e+09  48704.0  22.0  2024.0
#
#    Total_Purchases      Amount  Total_Amount  Ratings
# 0              3.0  108.028757    324.086270      5.0
# 1              2.0  403.353907    806.707815      4.0
# 2              3.0  354.477600   1063.432799      2.0
# 3              7.0  352.407717   2466.854021      4.0
# 4              2.0  124.276524    248.553049      1.0

# %%
cat_df = df[categorical_cols]

# %%
cat_df.head()
# Out:
#                   Name                Email                      Address  \
# 0  Michelle Harrington    Ebony39@gmail.com            3959 Amanda Burgs
# 1          Kelsey Hill     Mark36@gmail.com           82072 Dawn Centers
# 2         Scott Jensen    Shane85@gmail.com            4133 Young Canyon
# 3        Joseph Miller     Mary34@gmail.com  8148 Thomas Creek Suite 100
# 4        Debra Coleman  Charles30@gmail.com    5813 Lori Ports Suite 269
#
#          City            State    Country  Gender Income Customer_Segment  \
# 0    Dortmund           Berlin    Germany    Male    Low          Regular
# 1  Nottingham          England         UK  Female    Low          Premium
# 2     Geelong  New South Wales  Australia    Male    Low          Regular
# 3    Edmonton          Ontario     Canada    Male   High          Premium
# 4     Bristol          England         UK    Male    Low          Premium
#
#          Date      Month      Time Product_Category  Product_Brand  \
# ...

# %%
num_df
# Out:
#         Transaction_ID  Customer_ID         Phone  Zipcode   Age    Year  \
# 0            8691788.0      37249.0  1.414787e+09  77985.0  21.0  2023.0
# 1            2174773.0      69749.0  6.852900e+09  99071.0  19.0  2023.0
# 2            6679610.0      30192.0  8.362160e+09  75929.0  48.0  2023.0
# 3            7232460.0      62101.0  2.776752e+09  88420.0  56.0  2023.0
# 4            4983775.0      27901.0  9.098268e+09  48704.0  22.0  2024.0
# ...                ...          ...           ...      ...   ...     ...
# 302005       4246475.0      12104.0  7.466354e+09   4567.0  31.0  2024.0
# 302006       1197603.0      69772.0  5.754305e+09  16852.0  35.0  2023.0
# 302007       7743242.0      28449.0  9.382530e+09  88038.0  41.0  2024.0
# 302008       9301950.0      45477.0  9.373222e+09  67608.0  41.0  2023.0
# 302009       2882826.0      53626.0  9.518927e+09  25242.0  28.0  2024.0
#
#         Total_Purchases      Amount  Total_Amount  Ratings
# ...

# %%
cat_df['Customer_Segment'].value_counts()
# Out:
# Customer_Segment
# Regular    146221
# New         91187
# Premium     64387
# Name: count, dtype: int64

# %%
cat_df.head()
# Out:
#                   Name                Email                      Address  \
# 0  Michelle Harrington    Ebony39@gmail.com            3959 Amanda Burgs
# 1          Kelsey Hill     Mark36@gmail.com           82072 Dawn Centers
# 2         Scott Jensen    Shane85@gmail.com            4133 Young Canyon
# 3        Joseph Miller     Mary34@gmail.com  8148 Thomas Creek Suite 100
# 4        Debra Coleman  Charles30@gmail.com    5813 Lori Ports Suite 269
#
#          City            State    Country  Gender Income Customer_Segment  \
# 0    Dortmund           Berlin    Germany    Male    Low          Regular
# 1  Nottingham          England         UK  Female    Low          Premium
# 2     Geelong  New South Wales  Australia    Male    Low          Regular
# 3    Edmonton          Ontario     Canada    Male   High          Premium
# 4     Bristol          England         UK    Male    Low          Premium
#
#          Date      Month      Time Product_Category  Product_Brand  \
# ...

# %%
cat_df['Feedback'].value_counts()
# Out:
# Feedback
# Excellent    100755
# Good          95098
# Average       62674
# Bad           43299
# Name: count, dtype: int64

# %%
import seaborn as sns
import numpy as np

# %%
sns.displot(np.log(num_df['Age']),kind='kde')

# %%
import requests
from io import StringIO

url="https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day15%20-%20working%20with%20csv%20files/aug_train.csv"

headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv: 66.0) Gecko/20100101 Firefox/66.0"}

req= requests.get(url, headers=headers)
data =StringIO(req.text)
df1 = pd.read_csv(data)

# %%
df1.head(2)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0

# %%
df1.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df1.shape
# Out:
# (19158, 14)

# %%
df1.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
num_df
# Out:
#         Transaction_ID  Customer_ID         Phone  Zipcode   Age    Year  \
# 0            8691788.0      37249.0  1.414787e+09  77985.0  21.0  2023.0
# 1            2174773.0      69749.0  6.852900e+09  99071.0  19.0  2023.0
# 2            6679610.0      30192.0  8.362160e+09  75929.0  48.0  2023.0
# 3            7232460.0      62101.0  2.776752e+09  88420.0  56.0  2023.0
# 4            4983775.0      27901.0  9.098268e+09  48704.0  22.0  2024.0
# ...                ...          ...           ...      ...   ...     ...
# 302005       4246475.0      12104.0  7.466354e+09   4567.0  31.0  2024.0
# 302006       1197603.0      69772.0  5.754305e+09  16852.0  35.0  2023.0
# 302007       7743242.0      28449.0  9.382530e+09  88038.0  41.0  2024.0
# 302008       9301950.0      45477.0  9.373222e+09  67608.0  41.0  2023.0
# 302009       2882826.0      53626.0  9.518927e+09  25242.0  28.0  2024.0
#
#         Total_Purchases      Amount  Total_Amount  Ratings
# ...

# %%
cat_df.head(2)
# Out:
#                   Name              Email             Address        City  \
# 0  Michelle Harrington  Ebony39@gmail.com   3959 Amanda Burgs    Dortmund
# 1          Kelsey Hill   Mark36@gmail.com  82072 Dawn Centers  Nottingham
#
#      State  Country  Gender Income Customer_Segment        Date      Month  \
# 0   Berlin  Germany    Male    Low          Regular   9/18/2023  September
# 1  England       UK  Female    Low          Premium  12/31/2023   December
#
#        Time Product_Category Product_Brand Product_Type   Feedback  \
# 0  22:03:55         Clothing          Nike       Shorts  Excellent
# 1   8:42:04      Electronics       Samsung       Tablet  Excellent
#
#   Shipping_Method Payment_Method Order_Status        products
# 0        Same-Day     Debit Card      Shipped  Cycling shorts
# 1        Standard    Credit Card   Processing      Lenovo Tab

# %%
pd.options.display.max_columns=None

# %%
df.head(2)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
#
#           Phone             Address        City    State  Zipcode  Country  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund   Berlin  77985.0  Germany
# 1  6.852900e+09  82072 Dawn Centers  Nottingham  England  99071.0       UK
#
#     Age  Gender Income Customer_Segment        Date    Year      Month  \
# 0  21.0    Male    Low          Regular   9/18/2023  2023.0  September
# 1  19.0  Female    Low          Premium  12/31/2023  2023.0   December
#
#        Time  Total_Purchases      Amount  Total_Amount Product_Category  \
# 0  22:03:55              3.0  108.028757    324.086270         Clothing
# 1   8:42:04              2.0  403.353907    806.707815      Electronics
#
#   Product_Brand Product_Type   Feedback Shipping_Method Payment_Method  \
# ...

# %%
## handling  Date Columns
cat_df['month'] = cat_df['Date'].str.split('/').str[0]
cat_df['date'] = cat_df['Date'].str.split('/').str[1]
cat_df['year'] = cat_df['Date'].str.split('/').str[2]
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\3917882572.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df['month'] = cat_df['Date'].str.split('/').str[0]
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\3917882572.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df['date'] = cat_df['Date'].str.split('/').str[1]
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\3917882572.py:4: SettingWithCopyWarning:
# ...

# %%
cat_df['Time'].fillna(cat_df['Time'].mode()[0],inplace=True)
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\2835561389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df['Time'].fillna(cat_df['Time'].mode()[0],inplace=True)

# %%
cat_df['hours'] = cat_df['Time'].str.split(':').str[0].astype(int)
cat_df['minutes'] = cat_df['Time'].str.split(':').str[1].astype(int)
cat_df['seconds'] = cat_df['Time'].str.split(':').str[2].astype(int)
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\1036434542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df['hours'] = cat_df['Time'].str.split(':').str[0].astype(int)
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\1036434542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df['minutes'] = cat_df['Time'].str.split(':').str[1].astype(int)
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\1036434542.py:3: SettingWithCopyWarning:
# ...

# %%
cat_df.head(3)
# Out:
#                   Name              Email             Address        City  \
# 0  Michelle Harrington  Ebony39@gmail.com   3959 Amanda Burgs    Dortmund
# 1          Kelsey Hill   Mark36@gmail.com  82072 Dawn Centers  Nottingham
# 2         Scott Jensen  Shane85@gmail.com   4133 Young Canyon     Geelong
#
#              State    Country  Gender Income Customer_Segment        Date  \
# 0           Berlin    Germany    Male    Low          Regular   9/18/2023
# 1          England         UK  Female    Low          Premium  12/31/2023
# 2  New South Wales  Australia    Male    Low          Regular   4/26/2023
#
#        Month      Time Product_Category  Product_Brand Product_Type  \
# 0  September  22:03:55         Clothing           Nike       Shorts
# 1   December   8:42:04      Electronics        Samsung       Tablet
# 2      April   4:06:29            Books  Penguin Books   Children's
#
#     Feedback Shipping_Method Payment_Method Order_Status          products  \
# ...

# %%
cat_df[['month','date','year']].isnull().sum()
# Out:
# month    359
# date     359
# year     359
# dtype: int64

# %%
df1.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df1['experience_new'] = df1['experience'].str.replace('<','').str.replace('>','')

# %%
df1
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df1['company_size'].value_counts()
# Out:
# company_size
# 50-99        3083
# 100-500      2571
# 10000+       2019
# 10/49        1471
# 1000-4999    1328
# <10          1308
# 500-999       877
# 5000-9999     563
# Name: count, dtype: int64

# %%
df1['experience'].str.replace(r'[<>]', '', regex=True)
# Out:
# 0        20
# 1        15
# 2         5
# 3         1
# 4        20
#          ..
# 19153    14
# 19154    14
# 19155    20
# 19156     1
# 19157     2
# Name: experience, Length: 19158, dtype: object

# %%
dd = pd.DataFrame({
    'name':['<shoaib>','>amin kalim','=Taqfeeq'],
    'age':['22<>','33<','9<2=']
})

# %%
dd
# Out:
#           name   age
# 0     <shoaib>  22<>
# 1  >amin kalim   33<
# 2     =Taqfeeq  9<2=

# %%
dd['name'].str.replace('[<>=]','',regex=True)
# Out:
# 0        shoaib
# 1    amin kalim
# 2       Taqfeeq
# Name: name, dtype: object

# %%
dd['age'].str.replace('[<>=]','',regex=True).astype(int)
# Out:
# 0    22
# 1    33
# 2    92
# Name: age, dtype: int64

# %%
df1.sample()
# Out:
#        enrollee_id      city  city_development_index gender  \
# 11364        26626  city_102                   0.804    NaN
#
#            relevent_experience enrolled_university education_level  \
# 11364  Has relevent experience    Part time course        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 11364             STEM          8        10/49      Pvt Ltd            1
#
#        training_hours  target experience_new
# 11364              17     0.0              8

# %%
df.sample()
# Out:
#         Transaction_ID  Customer_ID            Name                 Email  \
# 102747       1745112.0      17235.0  Lori Daugherty  Kimberly20@gmail.com
#
#                Phone           Address   City    State  Zipcode Country   Age  \
# 102747  8.467957e+09  949 Olson Common  Leeds  England   6786.0      UK  46.0
#
#        Gender  Income Customer_Segment      Date    Year Month      Time  \
# 102747   Male  Medium              New  5/4/2023  2023.0   May  11:14:35
#
#         Total_Purchases      Amount  Total_Amount Product_Category  \
# 102747              7.0  406.088686   2842.620805         Clothing
#
#        Product_Brand Product_Type   Feedback Shipping_Method Payment_Method  \
# 102747          Nike      T-shirt  Excellent         Express     Debit Card
#
#        Order_Status  Ratings   products
# 102747      Shipped      4.0  Plain tee

# %%
df['Address'].head(20)
# Out:
# 0                  3959 Amanda Burgs
# 1                 82072 Dawn Centers
# 2                  4133 Young Canyon
# 3        8148 Thomas Creek Suite 100
# 4          5813 Lori Ports Suite 269
# 5         532 Ashley Crest Suite 014
# 6        600 Brian Prairie Suite 497
# 7                    237 Young Curve
# 8       8823 Mariah Heights Apt. 263
# 9                 6225 William Lodge
# 10                   9772 Sosa Coves
# 11      95471 Jerry Hollow Suite 034
# 12              60629 Jones Villages
# 13                 381 Richard Plaza
# 14    470 Rodriguez Estate Suite 564
# 15         3577 Cole Stream Apt. 351
# 16      93806 Murphy Avenue Apt. 919
# 17         9856 Meyers Road Apt. 698
# 18                 6048 Charles Lake
# 19      6048 Charles Knoll Suite 755
# Name: Address, dtype: object

# %%
df['Address'].str.findall(r'\d+')
# Out:
# 0              [3959]
# 1             [82072]
# 2              [4133]
# 3         [8148, 100]
# 4         [5813, 269]
#              ...
# 302005     [389, 159]
# 302006        [52809]
# 302007     [407, 495]
# 302008         [3204]
# 302009          [143]
# Name: Address, Length: 302010, dtype: object

# %%
df['Address'].str.extract(r'^(\d+)')
# Out:
#             0
# 0        3959
# 1       82072
# 2        4133
# 3        8148
# 4        5813
# ...       ...
# 302005    389
# 302006  52809
# 302007    407
# 302008   3204
# 302009    143
#
# [302010 rows x 1 columns]

# %%
df['Address'].str.replace(r'[0-9]', '', regex=True)
# Out:
# 0                   Amanda Burgs
# 1                   Dawn Centers
# 2                   Young Canyon
# 3            Thomas Creek Suite
# 4              Lori Ports Suite
#                    ...
# 302005           Todd Path Apt.
# 302006               Mark Forges
# 302007     Aaron Crossing Suite
# 302008                Baird Port
# 302009           Amanda Crescent
# Name: Address, Length: 302010, dtype: object

# %%
df.sample()
# Out:
#         Transaction_ID  Customer_ID          Name               Email  \
# 192202       4727571.0      78398.0  Alexis Bowen  Steven13@gmail.com
#
#                Phone           Address    City   State  Zipcode  Country  \
# 192202  2.132732e+09  2379 James Fords  Bochum  Berlin  11714.0  Germany
#
#          Age Gender Income Customer_Segment      Date    Year Month      Time  \
# 192202  48.0   Male    Low          Premium  6/7/2023  2023.0  June  12:48:16
#
#         Total_Purchases      Amount  Total_Amount Product_Category  \
# 192202              4.0  456.653677   1826.614706            Books
#
#         Product_Brand Product_Type Feedback Shipping_Method Payment_Method  \
# 192202  Penguin Books      Fiction  Average        Standard         PayPal
#
#        Order_Status  Ratings   products
# 192202    Delivered      2.0  Dystopian

# %%
df1.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df1['experience'].str.replace(r'[<>]','',regex=True)
# Out:
# 0        20
# 1        15
# 2         5
# 3         1
# 4        20
#          ..
# 19153    14
# 19154    14
# 19155    20
# 19156     1
# 19157     2
# Name: experience, Length: 19158, dtype: object

# %%
dt = pd.read_excel('flight_price.xlsx')

# %%
dt
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dt['Route'].str.split(r'→')
# Out:
# 0                      [BLR ,  DEL]
# 1        [CCU ,  IXR ,  BBI ,  BLR]
# 2        [DEL ,  LKO ,  BOM ,  COK]
# 3               [CCU ,  NAG ,  BLR]
# 4               [BLR ,  NAG ,  DEL]
#                     ...
# 10678                  [CCU ,  BLR]
# 10679                  [CCU ,  BLR]
# 10680                  [BLR ,  DEL]
# 10681                  [BLR ,  DEL]
# 10682    [DEL ,  GOI ,  BOM ,  COK]
# Name: Route, Length: 10683, dtype: object

# %%
dt['Route'].str.split(r'→').str[-1]
# Out:
# 0         DEL
# 1         BLR
# 2         COK
# 3         BLR
# 4         DEL
#          ...
# 10678     BLR
# 10679     BLR
# 10680     DEL
# 10681     DEL
# 10682     COK
# Name: Route, Length: 10683, dtype: object

# %%
dt['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
df2 = pd.DataFrame({
    'experience': ['>20', '<1', '5 years', '10+', '7yrs', 'three', None],
    'salary': ['$50,000', '₹7,20,000', '80k', '100000$', '€45.5k', 'N/A', None],
    'address': [
        '681 Pope Harbor Apt. 461',
        'No. 23, Baker Street',
        'Flat #12, 3084 Burton Prairie',
        'PO Box 789',
        'House-45B, Sector 9',
        None,
        'Near Gate 3, 9905 Crane Light'
    ],
    'phone': ['+1-234-567-8900', '(987) 654 3210', '91 98765 43210', '12345', None, 'phone missing', '+44 20 7946 0958'],
    'rating': ['4.5/5', '⭐⭐⭐⭐', '3 out of 5', 'five', '2.0', None, '★ ★ ★']
})

# %%
df2
# Out:
#   experience     salary                        address             phone  \
# 0        >20    $50,000       681 Pope Harbor Apt. 461   +1-234-567-8900
# 1         <1  ₹7,20,000           No. 23, Baker Street    (987) 654 3210
# 2    5 years        80k  Flat #12, 3084 Burton Prairie    91 98765 43210
# 3        10+    100000$                     PO Box 789             12345
# 4       7yrs     €45.5k            House-45B, Sector 9              None
# 5      three        N/A                           None     phone missing
# 6       None       None  Near Gate 3, 9905 Crane Light  +44 20 7946 0958
#
#        rating
# 0       4.5/5
# 1        ⭐⭐⭐⭐
# 2  3 out of 5
# 3        five
# 4         2.0
# 5        None
# 6       ★ ★ ★

# %%
## experience 
df2['experience'] = df2['experience'].str.replace(r'[<>+]','',regex=True)

# %%
df2['experience']
# Out:
# 0         20
# 1          1
# 2    5 years
# 3         10
# 4       7yrs
# 5      three
# 6       None
# Name: experience, dtype: object

# %%
df2['experience'].replace('three',3)
# Out:
# 0         20
# 1          1
# 2    5 years
# 3         10
# 4       7yrs
# 5          3
# 6       None
# Name: experience, dtype: object

# %%
df2['experience'].replace('three',3,inplace=True)

# %%
df2['experience'].str.extract('^(\d+)').fillna(0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_8336\1496526208.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df2['experience'].str.extract('^(\d+)').fillna(0)
#     0
# 0  20
# 1   1
# 2   5
# 3  10
# 4   7
# 5   0
# 6   0

# %%
df2['salary'].str.replace(',','').str.extract(r'(\d+)').fillna(0)
# Out:
#         0
# 0   50000
# 1  720000
# 2      80
# 3  100000
# 4      45
# 5       0
# 6       0

# %%
df2['salary']
# Out:
# 0      $50,000
# 1    ₹7,20,000
# 2          80k
# 3      100000$
# 4       €45.5k
# 5          N/A
# 6         None
# Name: salary, dtype: object

# %%
df2['salary'].str.replace(r'[^0-9.]','',regex=True)
# Out:
# 0     50000
# 1    720000
# 2        80
# 3    100000
# 4      45.5
# 5
# 6      None
# Name: salary, dtype: object

# %%
df2['salary'].astype(str).str.replace(r'[^0-9.]', '', regex=True)
# Out:
# 0     50000
# 1    720000
# 2        80
# 3    100000
# 4      45.5
# 5
# 6
# Name: salary, dtype: object
