# %% [markdown]
# # Operators

# %%
# Arthmatic Operation

a=10
b=15

add_result = a+b    # addition operation
sub_result = a-b    # subtraction operation
mul_result = a*b    # multiplication operatinon
div_result = a/b    # division operation
floor_div_result = a//b  # floor division
mod_result = a%b    # modulus operation
exponential_result = a**b

print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(mod_result)
print(exponential_result)
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 0
# 10
# 1000000000000000
