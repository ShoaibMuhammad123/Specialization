# %% [markdown]
# ## **Decision Tree Regressor Implimentation**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

# %%
## Data set description
print(dataset.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
dataset.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
## independent variable 
X= pd.DataFrame(dataset.data,columns=dataset.feature_names)

# %%
## dependent variable
y = pd.DataFrame(dataset.target)

# %%
X.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
#
# [5 rows x 10 columns]

# %%
y
# Out:
#          0
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# ..     ...
# 437  178.0
# 438  104.0
# 439  132.0
# 440  220.0
# 441   57.0
#
# [442 rows x 1 columns]

# %%
## splitting data 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=42)

# %%
X_train.head()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 17   0.070769  0.050680  0.012117  ...  0.034309  0.027364 -0.001078
# 66  -0.009147  0.050680 -0.018062  ...  0.071210  0.000272  0.019633
# 137  0.005383 -0.044642  0.049840  ... -0.002592  0.017036 -0.013504
# 245 -0.027310 -0.044642 -0.035307  ... -0.039493 -0.049872 -0.129483
# 31  -0.023677 -0.044642 -0.065486  ... -0.076395 -0.037129 -0.042499
#
# [5 rows x 10 columns]

# %%
y_train.head()
# Out:
#          0
# 17   144.0
# 66   150.0
# 137  280.0
# 245  125.0
# 31    59.0

# %%
## we now find the correlation
X_train.corr()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# age  1.000000  0.171161  0.184695  ...  0.180038  0.268422  0.281806
# sex  0.171161  1.000000  0.033934  ...  0.320490  0.113187  0.165951
# bmi  0.184695  0.033934  1.000000  ...  0.430974  0.468473  0.404928
# bp   0.314569  0.179283  0.394309  ...  0.212785  0.375295  0.374647
# s1   0.270283  0.021069  0.266467  ...  0.546840  0.528543  0.330773
# s2   0.218952  0.120205  0.261560  ...  0.654675  0.307139  0.293291
# s3  -0.043783 -0.355094 -0.354655  ... -0.736685 -0.372437 -0.288236
# s4   0.180038  0.320490  0.430974  ...  1.000000  0.613472  0.431352
# s5   0.268422  0.113187  0.468473  ...  0.613472  1.000000  0.478967
# s6   0.281806  0.165951  0.404928  ...  0.431352  0.478967  1.000000
#
# [10 rows x 10 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Applying **Decision Tree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtr.predict(X_test)

## evaluation
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print(mae)
print(mse)
print(r2)
# Out:
# 53.39325842696629
# 4534.112359550561
# 0.14420866468763538

# %% [markdown]
# ## **Hyperparameter Tuning**

# %%
params = {
    'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter':['best', 'random'],
    'max_depth':[1,2,3,4,5,10,15,20,25,30],
    'max_features': ['auto','sqrt', 'log2'],
}

# %%
dt_regressor = DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=dt_regressor,
                    param_grid=params,
                    cv= 5,
                    scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
grid.best_score_
# Out:
# np.float64(-4000.0421869381753)

# %%
## prediction 
y_pred = grid.predict(X_test)

# %%
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 51.0710008045281
# 3942.6348643250176
# 0.25584712339942073

# %% [markdown]
# ## To Visualize the Decision Tree Regressor we again train on this best parameters

# %%
dtr = DecisionTreeRegressor(criterion= 'poisson',
                            max_depth= 3,
                            max_features= 'log2',
                            splitter='best')

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=3, max_features='log2')

# %%
## visualizing the tree for regression 
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dtr,filled=True)
plt.show()
