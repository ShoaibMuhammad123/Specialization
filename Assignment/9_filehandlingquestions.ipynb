# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.
#
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.
#
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.
#
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.
#
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.
#
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.
#
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.
#
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.
#
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
with open('sample.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# This is the first line of the file
# Pakistan is the best country
# Human are very intelligent

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
list_of_str = ['First sentence\n','Second sentence\n','Third Sentence\n','Fourth Sentence']
with open('output.txt','w') as file:
    file.writelines(list_of_str)

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
with open('output.txt','r') as source_file:
    total_content = source_file.read()
    # print(total_content)
with open('destination.txt','w') as destination_file:
    destination_file.write(total_content)

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
def append_str_in_log(input_str):
    
    with open('log.txt','a') as file:
        file.write(input_str)
        
        
append_str_in_log("The sentence is appending.")

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
def total_words_in_document_file():
    total_words =0
    with open('document.txt') as file:
        for line in file:
            total_words+=len(line.split())
    return total_words

total_words = total_words_in_document_file()
print(total_words)
# Out:
# 7

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
def find_and_replace(word):
    with open('log.txt') as file:
        filedata = file.read()

    # assign the replaced string back to filedata
    filedata = filedata.replace('is', word)

    with open('log.txt', 'w') as file_write:
        file_write.write(filedata)

find_and_replace('SHOAIB')

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
def reverse_line():
    with open('log.txt','r') as file:
        for line in file:
            print(line[::-1])
            
reverse_line()
# Out:
# elif wen a si sihT
# .gnidneppa si ecnetnes ehT

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
def total_lines_words_characters():
    
    words,lines,characters =0,0,0
    
    with open('log.txt','r') as file:
        for line in file:
            lines += 1
            words += len(line.split())
            characters += len(line)
            
            
    return lines,words,characters

total_result = total_lines_words_characters()
print('Lines:',total_result[0])
print('Words:',total_result[1])
print('Characters:',total_result[2])
# Out:
# Lines: 2
# Words: 9
# Characters: 45

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merged_content():
    with open('output.txt','r') as output_file:
        first_file_data = output_file.read()
        
    with open('log.txt','r') as second_file:
        second_file_data = second_file.read()
        
    with open('merged.txt','w+') as file:
        file.write(first_file_data)
        file.write(second_file_data)
        
merged_content()

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
def split_file(filename, lines_per_file):
    with open(filename, 'r') as file:
        lines = file.readlines()
        # print(lines)
    for i in range(0, len(lines), lines_per_file):
        with open(f'{filename}_part{i//lines_per_file + 1}.txt', 'w') as part_file:
            part_file.writelines(lines[i:i + lines_per_file])
    
split_file('output.txt',1)
# Out:
# ['First sentence\n', 'Second sentence\n', 'Third Sentence\n', 'Fourth Sentence']

# %% [markdown]
# ### `What is Logging`
# `Logging is the process of recording events, messages, or information from a program while it is running. It helps developers understand what the program is doing, diagnose problems, and track behavior over time.`
#
# * Logging is helpful for:
#
#     - **Debugging** errors and crashes
#     - **Monitoring** application behavior in production
#     - **Tracking** user actions or system events
#     - **Auditing** and security review
#     - **Performance** analysis

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime

def log_message(message, filename='activity.log'):
    timestamp = datetime.datetime.now().isoformat()
    with open(filename, 'a') as file:
        file.write(f'[{timestamp}] {message}\n')

# Test
log_message('This is a log message.')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %%
def read_write_binary_file():
    with open('binary_file.bin','br') as file:
        content = file.read()
    with open('binary_file2.bin','bw') as file:
        file.write(content)
read_write_binary_file()

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %%
import csv
def function():
    with open('data.csv','r') as file:
        reader = csv.DictReader(file)
        print(reader)
        return list(reader)
    
function()
# Out:
# ...
# [{'Name': 'Shoaib', 'Age': '33', 'marks': '43'},
#  {'Name': 'khan', 'Age': '43', 'marks': '49'},
#  {'Name': 'asim', 'Age': '53', 'marks': '22'},
#  {'Name': 'muheeb', 'Age': '33', 'marks': '23'}]

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %%
import json 
def json_file_to_dictionary():
    with open('data.json') as file:
        data = json.load(file)
    return data
        
data = json_file_to_dictionary()
print(data)
print(type(data))
# Out:
# {'name': 'Shoaib', 'age': 23, 'city': 'Peshawar'}
# <class 'dict'>

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
def open_attempt_file():
    try:
        with open('protected.txt','r') as file:
            file_data = file.read()
            print(file_data)
    except PermissionError as e:
        print("You need to change you access mode because this error is occuring",e)
        
# open_attempt_file()

# %%
import datetime
def logging(message):
    with open('main.log', 'a') as file:
        file.write(f"[{datetime.datetime.now().isoformat()}] message: {message}")
        
logging("at this time the file has storing some log")
