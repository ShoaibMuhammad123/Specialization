# %% [markdown]
# # Module 5: Modules and Packages Assignments
# ## Lesson 5.1: Importing Modules
# ### Assignment 1: Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.
#
# ### Assignment 2: Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.
#
# ### Assignment 3: Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.
#
# ### Assignment 4: Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.
#
# ### Assignment 5: Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.
#
# ## Lesson 5.2: Standard Library Overview
# ### Assignment 6: Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.
#
# ### Assignment 7: Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.
#
# ### Assignment 8: Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.
#
# ### Assignment 9: Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.
#
# ### Assignment 10: Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.
#
# ## Lesson 5.3: Creating and Using Packages
# ### Assignment 11: Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.
#
# ### Assignment 12: Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.
#
# ### Assignment 13: Importing from a Package
#
# Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.
#
# ### Assignment 14: Relative Imports
#
# Create a subpackage named `subpackage` within `mypackage` and move `module2` into `subpackage`. Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.
#
# ### Assignment 15: Handling Package Import Errors
#
# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.

# %% [markdown]
# ### Assignment 1: Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.

# %%
import math 

## Taking root of 25
sqrt_value = math.sqrt(25)
## taking sine of 90
sine_value_of_90 = math.sin(90)

print(sqrt_value)
print(sine_value_of_90)
# Out:
# 5.0
# 0.8939966636005579

# %% [markdown]
# ### Assignment 2: Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.

# %%
import datetime as dt 
date_and_time = dt.datetime.now()

print(date_and_time)
# Out:
# 2025-12-01 14:51:52.095187

# %% [markdown]
# ### Assignment 3: Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.

# %%
from random import randint
print(randint(1,100))
# Out:
# 34

# %% [markdown]
# ### Assignment 4: Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.

# %%
from math import sqrt,pow 

root_value = sqrt(16)

power_value = pow(2,3)


print(root_value)
print(power_value)
# Out:
# 4.0
# 8.0

# %% [markdown]
# ### Assignment 5: Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.

# %%
try:
    import shoaib 
except:
    raise('The Module not exist')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 try:
# ----> 2     import shoaib
#       3 except:
#
# ModuleNotFoundError: No module named 'shoaib'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2     import shoaib
#       3 except:
# ----> 4     raise('The Module not exist')
#
# TypeError: exceptions must derive from BaseException

# %% [markdown]
# ## Lesson 5.2: Standard Library Overview
# ### Assignment 6: Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.

# %%
import os

os.mkdir('my_new_directory')
print(os.listdir('.'))
os.rmdir('my_new_directory')
print(os.listdir('.'))
# Out:
# ['1_assignment_question.ipynb', '1_assignment_solution.ipynb', '2_assignments2.ipynb', '2_assignment_solutions2.ipynb', '3_list_Assignment.ipynb', '3_list_assignment_solution.ipynb', '4_tuple_assignment.ipynb', '4_tuple_assignment_solution.ipynb', '5_sets_assignment.ipynb', '5_set_assignments_solution.ipynb', '6_dictionaries_assignment.ipynb', '6_dictionaries_assignment_solution.ipynb', '7_advancefunctions.ipynb', '7_advancefunctionsolution.ipynb', '8_packagesquestion.ipynb', '8_packagessolution.ipynb', 'my_new_directory', 'session_2_task.ipynb']
# ['1_assignment_question.ipynb', '1_assignment_solution.ipynb', '2_assignments2.ipynb', '2_assignment_solutions2.ipynb', '3_list_Assignment.ipynb', '3_list_assignment_solution.ipynb', '4_tuple_assignment.ipynb', '4_tuple_assignment_solution.ipynb', '5_sets_assignment.ipynb', '5_set_assignments_solution.ipynb', '6_dictionaries_assignment.ipynb', '6_dictionaries_assignment_solution.ipynb', '7_advancefunctions.ipynb', '7_advancefunctionsolution.ipynb', '8_packagesquestion.ipynb', '8_packagessolution.ipynb', 'session_2_task.ipynb']

# %% [markdown]
# ### Assignment 7: Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.

# %%
import sys 
print(sys.version)
print(sys.argv)
# Out:
# 3.12.12 | packaged by conda-forge | (main, Oct 22 2025, 23:13:34) [MSC v.1944 64 bit (AMD64)]
# ['C:\\Users\\PMYLS\\AppData\\Roaming\\Python\\Python312\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\PMYLS\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3380f735a8aea07e8a37f2255843c50fb42446803.json']

# %% [markdown]
# ### Assignment 8: Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.

# %%
import math

print(math.gcd(39,33))          # The GCD is the largest positive number that divides both a and b exactly (with no remainder).
print(math.factorial(5))
# Out:
# 3
# 120

# %% [markdown]
# ### Assignment 9: Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.

# %%
import datetime

future_date = datetime.date.today()+datetime.timedelta(100)
print(future_date)

date = datetime.date(2026,3,11)

date.strftime('%A')
# Out:
# 2026-03-11
# 'Wednesday'

# %% [markdown]
# ### Assignment 10: Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.

# %%
import random


lst1_random = [random.randint(1,50) for _ in range(5)]
print(lst1_random)

random.shuffle(lst1_random)
print(lst1_random)
# Out:
# [17, 16, 44, 14, 47]
# [44, 14, 17, 47, 16]

# %%
# Out:
# None

# %% [markdown]
# ## Lesson 5.3: Creating and Using Packages
# ### Assignment 11: Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.

# %%
## mypackage
        # __init__.py
        # module1
            # addition(a,b)
        # module2
            # multiply(a,b)
            
from mypackage.module1 import addition
from mypackage.module2 import multiply

print(addition(2,3))
print(multiply(4,3))
# Out:
# 5
# 12

# %% [markdown]
# ### Assignment 12: Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.

# %%
from mypackage import addition,multiply

print(addition(3,3))
print(multiply(8,2))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from mypackage import addition,multiply
#       3 print(addition(3,3))
#       4 print(multiply(8,2))
#
# ImportError: cannot import name 'addition' from 'mypackage' (unknown location)
